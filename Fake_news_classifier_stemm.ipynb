# %% [markdown]
# <a href="https://colab.research.google.com/github/narendrasingh125/Datasets-for-projects/blob/main/Fake_news_classifier_stemm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Files Data science/fake_newsData.csv')

# %%
# url = "https://raw.githubusercontent.com/krishnaik06/Fake-New-LSTM/refs/heads/master/FakeNewsClassifierUsingLSTM.ipynb"
# df1 = pd.read_csv(url)

# %%
# try:
#     df = pd.read_csv('/content/fake_newsData.csv',
#                      on_bad_lines='skip', # Skip lines with parsing errors
#                      quoting=csv.QUOTE_NONE, # Disable quoting to handle potential quote issues
#                      escapechar='\\')  # Escape special characters like backslashes
# except pd.errors.ParserError as e:
#     print(f"An error occurred while reading the CSV: {e}")

# %%
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
df.shape
# Out:
# (20800, 5)

# %%
df.describe()
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
df.columns
# Out:
# Index(['id', 'title', 'author', 'text', 'label'], dtype='object')

# %%
df=df.dropna()

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
df.shape
# Out:
# (18285, 5)

# %%
x=df.drop(['label'],axis=1)
y=df['label']

# %%
x.shape,y.shape
# Out:
# ((18285, 4), (18285,))

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.1'

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
### Vocabulary size
voc_size=5000

# %%
messages=x.copy()

# %%
messages['title'][1]
# Out:
# 'FLYNN: Hillary Clinton, Big Woman on Campus - Breitbart'

# %%
messages.head(20)
# Out:
#     id                                              title  \
# 0    0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1    1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2    2                  Why the Truth Might Get You Fired
# 3    3  15 Civilians Killed In Single US Airstrike Hav...
# 4    4  Iranian woman jailed for fictional unpublished...
# 5    5  Jackie Mason: Hollywood Would Love Trump if He...
# 7    7  Benoît Hamon Wins French Socialist Party’s Pre...
# 9    9  A Back-Channel Plan for Ukraine and Russia, Co...
# 10  10  Obama’s Organizing for Action Partners with So...
# 11  11  BBC Comedy Sketch "Real Housewives of ISIS" Ca...
# 12  12  Russian Researchers Discover Secret Nazi Milit...
# 13  13  US Officials See No Link Between Trump and Russia
# 14  14  Re: Yes, There Are Paid Government Trolls On S...
# 15  15  In Major League Soccer, Argentines Find a Home...
# 16  16  Wells Fargo Chief Abruptly Steps Down - The Ne...
# ...

# %%
messages.reset_index(inplace=True)

# %%
import nltk
import re
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
### Dataset Preprocessing
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['title'][i])
    review = review.lower()
    review = review.split()

    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus[:20]

# %%
onehot_repr=[one_hot(words,voc_size)for words in corpus]
onehot_repr[:20]

# %%
sent_length=20
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)

# %%
embedded_docs[0]

# %%
## Creating model
# embedding_vector_features=40
# model=Sequential()
# model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
# model.add(LSTM(100))
# model.add(Dense(1,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# print(model.summary())

# %%
# # prompt: create model

# embedding_vector_features=40
# model=Sequential()
# model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
# model.add(LSTM(100))
# model.add(Dense(1,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# print(model.summary())

# %%
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features)) # Remove input_length
model.add(LSTM(100))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.build((None, sent_length)) # Assuming your input shape is (batch_size, sent_length)
print(model.summary())

# %%
# y = np.array(y) # Convert y to NumPy array
# model.fit(embedded_docs,y,validation_split=0.2,epochs=10,batch_size=64)
# y_pred=model.predict_classes(embedded_docs)
# from sklearn.metrics import confusion_matrix
# confusion_matrix(y,y_pred)
# from sklearn.metrics import accuracy_score
# accuracy_score(y,y_pred)
# import numpy as np

# %%
len(embedded_docs),y.shape

# %%
import numpy as np
X_final=np.array(embedded_docs)
y_final=np.array(y)

# %%
X_final.shape,y_final.shape

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)

# %%
### Finally Training
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.7883 - loss: 0.4146 - val_accuracy: 0.9170 - val_loss: 0.1962
# Epoch 2/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.9426 - loss: 0.1451 - val_accuracy: 0.9196 - val_loss: 0.1939
# Epoch 3/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9660 - loss: 0.0951 - val_accuracy: 0.9153 - val_loss: 0.2042
# Epoch 4/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9746 - loss: 0.0741 - val_accuracy: 0.9115 - val_loss: 0.2427
# Epoch 5/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9851 - loss: 0.0491 - val_accuracy: 0.9044 - val_loss: 0.2673
# Epoch 6/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9879 - loss: 0.0406 - val_accuracy: 0.9097 - val_loss: 0.3374
# Epoch 7/10
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9934 - loss: 0.0231 - val_accuracy: 0.9090 - val_loss: 0.3644
# Epoch 8/10
# ...

# %%
from tensorflow.keras.layers import Dropout
## Creating model
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred < 0).astype(int)  # Convert probabilities to class labels (0 or 1)
# Out:
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step

# %%
pd.DataFrame(y_pred).value_counts()
# Out:
# 0
# 0    6035
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3419,    0],
#        [2616,    0]])

# %%
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
y_test
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5665285832642917
